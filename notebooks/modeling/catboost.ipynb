# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
from catboost import CatBoostClassifier, Pool

# Настройки отображения
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 30)
pd.options.display.float_format = '{:.2f}'.format

# Инициализация путей
root = Path(os.getcwd()).parent.parent
data_in = root / 'data' / 'processed_data'
data_out = root / 'data' / 'model_data'

print("Пути инициализированы:")
print(f"Processed data: {data_in}")
print(f"Model data: {data_out}")
# Out:
# Пути инициализированы:
# Processed data: /Users/aleksey.sushchikh/Desktop/GitHub/MIFIHackatonSberAutoSubscriptionAnalysis/data/processed_data
# Model data: /Users/aleksey.sushchikh/Desktop/GitHub/MIFIHackatonSberAutoSubscriptionAnalysis/data/model_data

# %%
# Загрузка данных
print("\nЗагружаем предобработанные данные...")
data = pd.read_pickle(data_in / 'test.pkl')
print("\nДанные успешно загружены!")
# Out:
# Загружаем предобработанные данные...
#
# Данные успешно загружены!

# %%
 def generate_summary(df: pd.DataFrame, name: str, sample_size: int = 3) -> None:
    """Генерация расширенной сводки по данным примерами"""
    print(f"\n{'='*50} {name.upper()} {'='*50}")
    print(f"Общее количество записей: {df.shape[0]:,}")
    print(f"Количество признаков: {df.shape[1]}")
    
    # Типы данных
    print("\nТипы данных:")
    print(df.dtypes.value_counts().rename('count').to_frame())
    
    # Пропуски
    missing = df.isna().sum().sort_values(ascending=False)
    missing_pct = (missing / df.shape[0] * 100).round(2)
    missing_df = pd.concat([missing, missing_pct], axis=1, keys=['count', '%']).query('count > 0')
    if not missing_df.empty:
        print("\nПропущенные значения:")
        print(missing_df)
    else:
        print("\nПропущенных значений нет")
        
    # Дубликаты
    dupes = df.duplicated().sum()
    print(f"\nДубликаты: {dupes} ({dupes/df.shape[0]*100:.2f}%)")
    
    # Примеры
    print(f"\nПервые {sample_size} записей:")
    display(df.head(sample_size))


def analyze_column(df: pd.DataFrame, col: str, max_display: int = 50) -> None:
    """Полный анализ колонки с выводом всех уникальных значений"""
    print(f"\n{'-'*60}")
    print(f"Полный анализ колонки: {col}")
    
    # Проверка существования колонки
    if col not in df.columns:
        print(f"Колонка {col} не найдена!")
        return
    
    # Пропуски
    na_count = df[col].isna().sum()
    print(f"Пропуски: {na_count} ({na_count/len(df)*100:.1f}%)")

    # Количество уникальных значений
    unique_count = df[col].nunique(dropna=False)
    print(f"Уникальных значений: {unique_count}")
    
    # Вывод всех значений для категориальных данных
    if unique_count <= max_display:
        print("\nВсе значения:")
        print(df[col].unique())
    else:
        print(f"\nСлишком много значений (> {max_display}). Примеры:")
        print(df[col].dropna().sample(10).unique())
        
    # Частотный анализ для числовых колонок
    if pd.api.types.is_numeric_dtype(df[col]):
        print("\nОписательная статистика:")
        print(df[col].describe())
    else:
        print("\nТоп-10 значений:")
        print(df[col].value_counts(dropna=False).head(10))

# %%
# Объявляем целевые действия
target_actions = [
    # Отправка форм и заявок
    'sub_submit_success', 'sub_submit_error',          # sub_submit
    'form_request_call_sent',                          # phone
    'sub_callback_submit_click',                       # sub_button_click
    'sub_car_request_submit_click',                    # sub_button_click
    'sub_custom_question_submit_click',                # sub_button_click
    'sub_car_claim_submit_click',                      # sub_button_click

    # Обратный звонок и контакт
    'click_on_request_call', 'click_on_phone',          # phone
    'phone_entered_on_form_request_call',               # phone
    'showed_form_request_call',                         # phone

    # Чат и онлайн-диалог
    'start_chat', 'chat requested',                     # chat, jivosite
    'user_message', 'client initiate chat',             # chat, jivosite
    'callback requested',                               # jivosite
    'offline form shown',                               # jivosite

    # Аутентификация (сильный признак санкционированного взаимодействия)
    'phone_auth_success', 'sber_id_auth_success',       # auth

    # Кредит и рассчет
    'calculate',                                        # credit_landing_pos
    'request', 'request_success',                       # credit_landing_pos

    # Клики по покупке/оформлению подписки
    'click_on_subscription',                            # header, main_banners
    'click_auto_subscription',                          # main_services
    'click_free_car_selection',                         # main_services, chat
    'click_buy_auto',                                   # main_advantages, main_services
    'click_auto',                                       # main_services
    'click_car_selection',                              # main_services
    'click_car_buyback',                                # header, main_services
    'click_setelem_credit',                             # main_services
    'click_pos_credit',                                 # main_services

    # Публикация объявления (для частных продавцов)
    'success_ad_creation',                              # add_ad_publish_success

    # Запросы по VIN, цене, городу — сильный признак готовности
    'forward_to_price', 'sap_search_form_cost_to',      # add_ad_city, sap_search_form
    'sap_search_form_cost_from',                       # sap_search__form

    # Переходы из листинга и карточки
    'go_to_car_card',                                   # listing_ads, greenday_listing_ads
    'sub_view_cars_click',                              # sub_button_click, greenday_gtm.triggergroup

    # Клики из “подписаться”
    'sub_open_dialog_click',                            # sub_button_click, greenday_sub_button_click

    # Дополнительные целевые события
    'request',                                          # credit_landing_pos (повтор)
    'order_call',                                       # если встречается в схеме
]

data['is_target'] = data['event_action'].isin(target_actions).astype('int')

generate_summary(data, "Данные")
for col in data.columns:
    analyze_column(data, col, max_display=100)
# Out:
# ================================================== ДАННЫЕ ==================================================
# Общее количество записей: 15,854,246
# Количество признаков: 29
#
# Типы данных:
#          count
# object      25
# float64      3
# int64        1
#
# Пропущенные значения:
#                              count      %
# event_value               15854246 100.00
# device_model              15730683  99.22
# utm_keyword                9307387  58.71
# hit_time                   9288098  58.58
# device_os                  9255807  58.38
# hit_referer                6402580  40.38
# event_label                3887960  24.52
# utm_adcontent              2905147  18.32
# utm_campaign               2264440  14.28
# device_brand               1406759   8.87
# event_action                127776   0.81
# event_category              127776   0.81
# hit_page_path               127776   0.81
# hit_type                    127776   0.81
# hit_number                  127776   0.81
# hit_date                    127776   0.81
# utm_source                   41972   0.26
# visit_time                   41251   0.26
# visit_date                   41251   0.26
# geo_city                     41251   0.26
# geo_country                  41251   0.26
# device_browser               41251   0.26
# client_id                    41251   0.26
# visit_number                 41251   0.26
# device_category              41251   0.26
# utm_medium                   41251   0.26
# device_screen_resolution     41251   0.26
#
# Дубликаты: 0 (0.00%)
#
# Первые 3 записей:
#                       session_id             client_id  visit_date visit_time  \
# 0  1000009318903347362.163266...  232832813.1632663714  2021-09-26   16:00:00
# 1  1000009318903347362.163266...  232832813.1632663714  2021-09-26   16:00:00
# 2  1000009318903347362.163266...  232832813.1632663714  2021-09-26   16:00:00
#
#    visit_number            utm_source utm_medium          utm_campaign  \
# 0          1.00  MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 1          1.00  MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 2          1.00  MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
#
#           utm_adcontent utm_keyword device_category device_os device_brand  \
# 0  PkybGvWbaqORmxjNunqZ         NaN          mobile      None      Samsung
# 1  PkybGvWbaqORmxjNunqZ         NaN          mobile      None      Samsung
# 2  PkybGvWbaqORmxjNunqZ         NaN          mobile      None      Samsung
#
#   device_model device_screen_resolution device_browser geo_country  \
# 0          NaN                  412x869         Chrome      Russia
# 1          NaN                  412x869         Chrome      Russia
# 2          NaN                  412x869         Chrome      Russia
#
#      geo_city    hit_date  hit_time  hit_number hit_type  \
# 0  Gelendzhik  2021-09-26       NaN       15.00    event
# 1  Gelendzhik  2021-09-26       NaN        3.00    event
# 2  Gelendzhik  2021-09-26       NaN        4.00    event
#
#             hit_referer                  hit_page_path event_category  \
# 0  HbolMJUevblAbkHClEQa  podpiska.sberauto.com/faq?...  sub_page_view
# 1  HbolMJUevblAbkHClEQa         podpiska.sberauto.com/  sub_page_view
# 2  HbolMJUevblAbkHClEQa         podpiska.sberauto.com/    listing_ads
#
#      event_action           event_label event_value  is_target
# 0         sub_faq  KclpemfoHstknWHFiLit        None          0
# 1     sub_landing  KclpemfoHstknWHFiLit        None          0
# 2  go_to_car_card  hAHqGICPFQiPwtzubOzs        None          1
# ------------------------------------------------------------
# Полный анализ колонки: session_id
# Пропуски: 0 (0.0%)
# Уникальных значений: 1862386
#
# Слишком много значений (> 100). Примеры:
# ['7364072604327003426.1629013286.1629013286'
#  '6463262982762317232.1635435954.1635435954'
#  '1522768149475896693.1625846928.1625846928'
#  '5314216535080831161.1627900419.1627900472'
#  '1017030948615564254.1640967135.1640967135'
#  '675837157473929879.1631472279.1631472279'
#  '5836906139387411878.1635499430.1635499430'
#  '2069057727194157792.1630825804.1630825804'
#  '536440961643253619.1639383543.1639383543'
#  '4563409153123369468.1622098427.1622098772']
#
# Топ-10 значений:
# session_id
# 5442565791571325612.1632449195.1632449195    768
# 6568868914238486437.1632270313.1632270313    678
# 5959671972744778783.1632490527.1632490600    548
# 7452598043578978502.1632358598.1632358598    514
# 3070792010704358528.1629752408.1629752408    498
# 686125592720823356.1634587719.1634587719     496
# 8115026869866033734.1629319807.1629319807    496
# 6841198707279638061.1631825458.1631825458    496
# 3740600179229362264.1639614533.1639614533    496
# 1191055000444557028.1634948839.1634948839    492
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: client_id
# Пропуски: 41251 (0.3%)
# Уникальных значений: 1391720
#
# Слишком много значений (> 100). Примеры:
# ['1718655752.1634217880' '1837408219.1627870206' '1799707564.1640347859'
#  '739287607.1632291573' '1603306396.1634569955' '1323894425.1630669280'
#  '1720656346.1635249991' '727047300.1633693956' '349799062.1635250760'
#  '285961.1631559126']
#
# Топ-10 значений:
# client_id
# NaN                      41251
# 1750498477.1629450062     6884
# 736859557.1619557452      5877
# 1485840051.1622209619     3641
# 1216284533.1631197504     3409
# 106350095.1635936693      2778
# 471358394.1635690930      2560
# 1136708344.1633419274     2508
# 319254641.1622131418      2328
# 1004110209.1631686929     2143
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: visit_date
# Пропуски: 41251 (0.3%)
# Уникальных значений: 227
#
# Слишком много значений (> 100). Примеры:
# [datetime.date(2021, 12, 25) datetime.date(2021, 12, 15)
#  datetime.date(2021, 5, 24) datetime.date(2021, 12, 21)
#  datetime.date(2021, 6, 13) datetime.date(2021, 10, 19)
#  datetime.date(2021, 10, 17) datetime.date(2021, 6, 10)
#  datetime.date(2021, 11, 14)]
#
# Топ-10 значений:
# visit_date
# 2021-05-24    513258
# 2021-12-21    280462
# 2021-05-25    235950
# 2021-09-23    167618
# 2021-05-26    159032
# 2021-09-24    153123
# 2021-06-29    153121
# 2021-09-14    144243
# 2021-06-28    134877
# 2021-09-22    132375
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: visit_time
# Пропуски: 41251 (0.3%)
# Уникальных значений: 85319
#
# Слишком много значений (> 100). Примеры:
# [datetime.time(21, 0) datetime.time(23, 0) datetime.time(13, 0)
#  datetime.time(0, 0) datetime.time(22, 0) datetime.time(15, 41, 33)
#  datetime.time(17, 44, 28) datetime.time(16, 0) datetime.time(14, 0)]
#
# Топ-10 значений:
# visit_time
# 13:00:00    547525
# 12:00:00    541944
# 14:00:00    540184
# 16:00:00    531625
# 11:00:00    528030
# 15:00:00    525056
# 10:00:00    521014
# 22:00:00    509520
# 21:00:00    494542
# 17:00:00    488154
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: visit_number
# Пропуски: 41251 (0.3%)
# Уникальных значений: 538
#
# Слишком много значений (> 100). Примеры:
# [1. 2.]
#
# Описательная статистика:
# count   15812995.00
# mean           2.71
# std           12.56
# min            1.00
# 25%            1.00
# 50%            1.00
# 75%            2.00
# max          564.00
# Name: visit_number, dtype: float64
#
# ------------------------------------------------------------
# Полный анализ колонки: utm_source
# Пропуски: 41972 (0.3%)
# Уникальных значений: 294
#
# Слишком много значений (> 100). Примеры:
# ['fDLlAcSmythWSCVMvqvL' 'bByPQxmDaMXgpHeypKSM' 'vFcAhRxLfOWKhvxjELkx'
#  'kjsLglQLzykiRbcDiGcD' 'ZpYIoDJMcFzVoPFsHGJL']
#
# Топ-10 значений:
# utm_source
# ZpYIoDJMcFzVoPFsHGJL    5177437
# fDLlAcSmythWSCVMvqvL    3274441
# kjsLglQLzykiRbcDiGcD    1793607
# bByPQxmDaMXgpHeypKSM    1353734
# BHcvLfOaCWvWTykYqHVe    1236428
# MvfHsxITijuriZxsqZqt     584822
# QxAxdyPLuQMEcrdZWdWb     449334
# aXQzDWsJuGXeBXexNHjc     387962
# RmEBuqrriAfAVsLQQmhk     281057
# jaSOmLICuBzCFqHfBdRg     242010
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: utm_medium
# Пропуски: 41251 (0.3%)
# Уникальных значений: 57
#
# Все значения:
# ['cpm' '(none)' 'banner' 'cpc' 'email' 'organic' 'cpa' 'referral'
#  'stories' 'smm' 'cpv' 'push' 'blogger_stories' 'tg' 'blogger_channel'
#  'smartbanner' 'app' 'blogger_header' 'post' nan 'outlook' 'nkp'
#  'info_text' '(not set)' 'clicks' 'vk_smm' 'users_msk' 'static' 'sms'
#  'ok_smm' 'fb_smm' 'google_cpc' 'partner' 'cbaafe' 'Sbol_catalog'
#  'landing' 'landing_interests' 'yandex_cpc' 'web_polka' 'linktest'
#  'article' 'sber_app' 'CPM' 'medium' 'tablet' 'promo_sbol' 'reach'
#  'desktop' 'dom_click' 'social' 'catalogue' 'main_polka' 'last' 'link'
#  'qrcodevideo' 'promo_sber' 'qr']
#
# Топ-10 значений:
# utm_medium
# banner             4925629
# cpc                3335902
# (none)             3274441
# referral           1935658
# cpm                 751057
# organic             654207
# push                253189
# email               242037
# stories              95714
# blogger_channel      87371
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: utm_campaign
# Пропуски: 2264440 (14.3%)
# Уникальных значений: 413
#
# Слишком много значений (> 100). Примеры:
# ['gecBYcKZCPMcVYdSSzKP' 'LEoPHuyFvzoNfnzGgfcd' 'UvuMsOSDBWQGOIbDbXfV'
#  'LTuZkdKfxRGVceoWkVyg' 'ESphyUeLTPINiYALHWrO']
#
# Топ-10 значений:
# utm_campaign
# LTuZkdKfxRGVceoWkVyg    5207010
# LEoPHuyFvzoNfnzGgfcd    3180023
# NaN                     2264440
# gecBYcKZCPMcVYdSSzKP    1139342
# FTjNLDyTrXaWYgZymFkV     763369
# okTXSMadDkjvntEHzIjp     185765
# sbJRYgVfvcnqKJNDDYIr     184266
# SgIUDYUKnyWHVowUOqid     180944
# TmThBvoCcwkCZZUWACYq     167548
# bxOTvPtyGSdUrbwoXCPO     117590
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: utm_adcontent
# Пропуски: 2905147 (18.3%)
# Уникальных значений: 287
#
# Слишком много значений (> 100). Примеры:
# ['JNHcPlZPxEMWDnRiyoBf' 'LLfCasrxQzJIyuldcuWy']
#
# Топ-10 значений:
# utm_adcontent
# JNHcPlZPxEMWDnRiyoBf    9718856
# NaN                     2905147
# vCIpmpaGBnIQhyYNkXqp    1808247
# xhoenQgDQsgfEPYNPwKO     353762
# PkybGvWbaqORmxjNunqZ     200735
# LLfCasrxQzJIyuldcuWy     182253
# SOkCdPxfUcZUzzOdgGES      78814
# yYdBRbPmBMUZHXwqGxNx      69889
# nNqUcgFgcqQbTVSvgaHr      60420
# XSkXBCPfnJjvxbfeewtd      52917
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: utm_keyword
# Пропуски: 9307387 (58.7%)
# Уникальных значений: 1220
#
# Слишком много значений (> 100). Примеры:
# ['puhZPIYqKXeFPaUviSjo' 'CHdbSXINvRmKaAtGIGzz']
#
# Топ-10 значений:
# utm_keyword
# NaN                     9307387
# puhZPIYqKXeFPaUviSjo    4757951
# aXQzDWsJuGXeBXexNHjc     182540
# ITfrGJNwVsHBGJMAKoct     139286
# UKNBOHebRIIsQRsjNKay     133288
# hAmNSZmQkKQKAjZEGlgb      96837
# JajANoFxoqXfKRNBUhzx      88273
# XEayFbemrPYbxFeNbxif      47306
# tVtbIKrPSOvrXLCznVVe      41618
# ZNhSIPchlbnKwZWcsKzz      41114
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_category
# Пропуски: 41251 (0.3%)
# Уникальных значений: 4
#
# Все значения:
# ['mobile' 'desktop' 'tablet' nan]
#
# Топ-10 значений:
# device_category
# mobile     11701733
# desktop     3965226
# tablet       146036
# NaN           41251
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_os
# Пропуски: 9255807 (58.4%)
# Уникальных значений: 15
#
# Все значения:
# [None 'Android' 'iOS' 'Macintosh' 'Windows' 'Linux' nan 'Chrome OS'
#  '(not set)' 'BlackBerry' 'Tizen' 'Firefox OS' 'Samsung' 'Windows Phone'
#  'Nokia']
#
# Топ-10 значений:
# device_os
# None          9214556
# Android       3472049
# iOS           1760463
# Windows       1022091
# Macintosh      311143
# NaN             41251
# Linux           31436
# (not set)         503
# Chrome OS         378
# BlackBerry        214
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_brand
# Пропуски: 1406759 (8.9%)
# Уникальных значений: 208
#
# Слишком много значений (> 100). Примеры:
# ['Huawei' 'Apple' '' 'Samsung']
#
# Топ-10 значений:
# device_brand
# Apple        4756207
# Samsung      2630322
#              2600349
# Xiaomi       2090364
# Huawei       1382050
# None         1365508
# Realme        144015
# (not set)     133928
# OnePlus        93163
# OPPO           92717
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_model
# Пропуски: 15730683 (99.2%)
# Уникальных значений: 105
#
# Слишком много значений (> 100). Примеры:
# ['tWBQlsvNfHxRUjaPAfhd' 'mzJXHtJPIOSHoHtgezIA' 'WjsFbaSQmnGghVzNcrpJ'
#  'AuMdmADEIoPXiWpTsBEj' 'pTgAEPipQxDXCjPrJbHo' 'pcvPxfVFaAmhwFmvIeYd'
#  'ZkRlaMsFhSBPslXBtfiG']
#
# Топ-10 значений:
# device_model
# NaN                     15730683
# AuMdmADEIoPXiWpTsBEj       79081
# tWBQlsvNfHxRUjaPAfhd        4396
# pTgAEPipQxDXCjPrJbHo        3526
# cwMJxNXiWUgMUxGiCTPs        3077
# tfPZFRbtlzEssBEesRwM        2576
# FJApgTrMAGHoxCxQVKws        2413
# pcvPxfVFaAmhwFmvIeYd        2180
# aCLaTVQlHcXbUnQYQvIg        2069
# mzJXHtJPIOSHoHtgezIA        1687
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_screen_resolution
# Пропуски: 41251 (0.3%)
# Уникальных значений: 5040
#
# Слишком много значений (> 100). Примеры:
# ['428x926' '412x915' '1536x864' '393x873' '854x534' '1360x768' '414x896'
#  '1280x800' '393x851' '375x812']
#
# Топ-10 значений:
# device_screen_resolution
# 414x896      1494183
# 1920x1080    1399348
# 375x812      1047632
# 393x851       912995
# 375x667       759542
# 360x780       737589
# 412x915       660432
# 360x800       627352
# 390x844       554401
# 393x873       479390
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: device_browser
# Пропуски: 41251 (0.3%)
# Уникальных значений: 58
#
# Все значения:
# ['Chrome' 'Samsung Internet' 'Safari' 'YaBrowser' 'Edge' 'Android Webview'
#  'Safari (in-app)' 'Firefox' 'Opera' 'Internet Explorer' nan '[FBAN'
#  'UC Browser' 'Opera Mini' 'Puffin' 'Instagram 209.0.0.21.119 Android'
#  'Mozilla Compatible Agent' 'Android Runtime'
#  'Instagram 208.0.0.32.135 Android' 'Instagram 202.0.0.23.119'
#  'Instagram 213.0.0.29.120 Android' 'Android' 'com.vk.vkclient'
#  'Android Browser' 'Maxthon' 'Instagram 207.0.0.28.118'
#  'Instagram 216.0.0.12.135' 'Instagram 216.1.0.21.137 Android' 'MRCHROME'
#  'helloworld' 'Instagram 199.1.0.34.119 Android'
#  'Instagram 192.0.0.37.119' 'Amazon Silk' 'SeaMonkey'
#  'Instagram 194.0.0.36.172 Android' 'Instagram 202.0.0.37.123 Android'
#  'MyApp' '(not set)' 'Coc Coc' 'NetFront' 'Instagram 201.0.0.23.111'
#  'Instagram 203.0.0.26.117' 'Mozilla' 'Instagram 192.0.0.35.123 Android'
#  'Instagram 212.0.0.38.119 Android' 'Instagram 208.0.0.26.131' 'MT6735_TD'
#  'Instagram 199.0.0.27.120' 'NokiaX2-02'
#  'Instagram 158.0.0.30.123 Android' 'Nokia501'
#  'Instagram 206.1.0.34.121 Android' 'Phantom Browser'
#  'com.zhiliaoapp.musically' 'Konqueror' 'Instagram 213.0.0.19.117' 'Iron'
#  'Threads 202.0.0.23.119']
#
# Топ-10 значений:
# device_browser
# Chrome              8259079
# Safari              4246902
# YaBrowser           1325061
# Safari (in-app)      643659
# Android Webview      461524
# Samsung Internet     265477
# Firefox              207741
# Opera                198730
# Edge                 194970
# NaN                   41251
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: geo_country
# Пропуски: 41251 (0.3%)
# Уникальных значений: 167
#
# Слишком много значений (> 100). Примеры:
# ['Belarus' 'Russia']
#
# Топ-10 значений:
# geo_country
# Russia            15389050
# Ukraine              76840
# NaN                  41251
# United States        38032
# Belarus              30003
# Germany              25263
# Turkey               18719
# Kazakhstan           16748
# Netherlands          15087
# United Kingdom       14007
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: geo_city
# Пропуски: 41251 (0.3%)
# Уникальных значений: 2549
#
# Слишком много значений (> 100). Примеры:
# ['Saint Petersburg' 'Krasnoyarsk' 'Moscow' 'Klimovsk' 'Rostov-on-Don']
#
# Топ-10 значений:
# geo_city
# Moscow              6849519
# Saint Petersburg    2383906
# (not set)            601154
# Yekaterinburg        330534
# Krasnodar            295484
# Kazan                277798
# Samara               228334
# Nizhny Novgorod      201471
# Ufa                  198589
# Novosibirsk          192369
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_date
# Пропуски: 127776 (0.8%)
# Уникальных значений: 227
#
# Слишком много значений (> 100). Примеры:
# [datetime.date(2021, 6, 24) datetime.date(2021, 7, 3)
#  datetime.date(2021, 8, 15) datetime.date(2021, 6, 15)
#  datetime.date(2021, 10, 17) datetime.date(2021, 12, 28)
#  datetime.date(2021, 10, 15) datetime.date(2021, 7, 26)
#  datetime.date(2021, 6, 29) datetime.date(2021, 10, 20)]
#
# Топ-10 значений:
# hit_date
# 2021-05-24    513035
# 2021-12-21    280192
# 2021-05-25    235805
# 2021-09-23    168899
# 2021-05-26    158382
# 2021-09-24    153241
# 2021-06-29    152641
# 2021-09-14    143624
# 2021-06-28    134588
# 2021-09-22    133147
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_time
# Пропуски: 9288098 (58.6%)
# Уникальных значений: 925888
#
# Слишком много значений (> 100). Примеры:
# [ 43708. 581463. 195416. 170100. 717480. 594729. 211451. 410310.   7230.
#   49177.]
#
# Описательная статистика:
# count    6566148.00
# mean      209104.99
# std       403210.97
# min            0.00
# 25%        24120.00
# 50%        89941.00
# 75%       219535.25
# max     13156885.00
# Name: hit_time, dtype: float64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_number
# Пропуски: 127776 (0.8%)
# Уникальных значений: 501
#
# Слишком много значений (> 100). Примеры:
# [11.  7.  9.  4.  5. 10. 30. 15.]
#
# Описательная статистика:
# count   15726470.00
# mean          23.57
# std           28.88
# min            1.00
# 25%            7.00
# 50%           15.00
# 75%           29.00
# max          500.00
# Name: hit_number, dtype: float64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_type
# Пропуски: 127776 (0.8%)
# Уникальных значений: 2
#
# Все значения:
# ['event' nan]
#
# Топ-10 значений:
# hit_type
# event    15726470
# NaN        127776
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_referer
# Пропуски: 6402580 (40.4%)
# Уникальных значений: 37874
#
# Слишком много значений (> 100). Примеры:
# ['HbolMJUevblAbkHClEQa' 'sAGDBCdeVPmQPwkVEcIX']
#
# Топ-10 значений:
# hit_referer
# HbolMJUevblAbkHClEQa    8879187
# NaN                     6402580
# FwdMTcXzWAwhtsnMAbhS      91940
# sAGDBCdeVPmQPwkVEcIX      53565
# GQmOLxANuSeCxCanBpMl      35470
# ZeRnFrHdnMmnqraghdGJ      23016
# CENJYQocGncDfpQMoNnT      16787
# NfSAiKHBqffzsXrbjcSr      14949
# trXmoxcphNjuYcShOXwL      10325
# eAbATQERmGPolIKkWXkU       8231
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: hit_page_path
# Пропуски: 127776 (0.8%)
# Уникальных значений: 342716
#
# Слишком много значений (> 100). Примеры:
# ['sberauto.com/cars/95eb25d5?utm_source_initial=google&utm_medium_initial=cpc&utm_campaign_initial=nSReTmyFtbSjlPrTKoaX|ZxCjNTHeXPmooDEOFIuR&utm_content_initial=yXzSAJWSuRbYeLFyMVFl|nxheuoccCUneLBnHdxMC|xAEYTlJDbQNwQTLGxICQ|tdkLuROGZtRLOEIAAKmP|lFpAoUqEvHoyZfCNRuCR|OiHVFcVxQOStkNHpqDCV|dtYJKUplNmmKCOfiziff|BECmuFKBxdPEqNJhHcnw|aHSPdWXGkJravzWuwcJA|HbolMJUevblAbkHClEQa|kqZPVvZmXADsCZxIQwbv|QaGunexmXrztCWbLcYxs|OfdDOXSwHYclonQJpPxh|LlKfVNOXVlphfZnsKToZ|HbolMJUevblAbkHClEQa&utm_term_initial=ITfrGJNwVsHBGJMAKoct&rental_page=rental_car'
#  'sberauto.com/cars?city=1&rental_page=rental_only&rental_car=rental_only&city=18'
#  'sberauto.com/cars?utm_source_initial=sbol&utm_medium_initial=banner&utm_campaign_initial=LEoPHuyFvzoNfnzGgfcd&city=1&rental_page=rental_only&rental_car=rental_only&city=18'
#  'sberauto.com/cars/all/kia/seltos/20f30855?utm_source_initial=yandex&utm_medium_initial=cpc&utm_campaign_initial=DsqwamlMwRgMTyspCjFR|gDchtZpzPhEcUUlQzgsT&utm_content_initial=yXzSAJWSuRbYeLFyMVFl|shhJpwqRdkvQHnFvfjmR|xAEYTlJDbQNwQTLGxICQ|kAorzKQwnYtRjsKapPZQ|lFpAoUqEvHoyZfCNRuCR|IDYAuOlAsvejGllgVmnx|rjbbNGNkjGThUJNtsWZQ|HZnnAJEbUDmoOtkVhhMS|ZIKCVYXYgRrZdwlVkEEf|HbolMJUevblAbkHClEQa|kqZPVvZmXADsCZxIQwbv|vnTlRpYmthtVDImMLSmr|OfdDOXSwHYclonQJpPxh|YhdYMAYSoTzDKQYzVVMr|HbolMJUevblAbkHClEQa&utm_term_initial=&rental_page=rental_car'
#  'sberauto.com/cars/b0969889?rental_page=rental_car'
#  'sberauto.com/cars/all/mercedes-benz/glc/f8f3304e?rental_page=rental_car'
#  'podpiska.sberauto.com/?yclid=16388360106515890175']
#
# Топ-10 значений:
# hit_page_path
# podpiska.sberauto.com/                                                                                                                                                                                                  2793639
# sberauto.com/cars?city=1&rental_page=rental_only&rental_car=rental_only&city=18                                                                                                                                         1103484
# sberauto.com/cars?utm_source_initial=sbol&utm_medium_initial=banner&utm_campaign_initial=LEoPHuyFvzoNfnzGgfcd&utm_content_initial=vCIpmpaGBnIQhyYNkXqp&city=1&rental_page=rental_only&rental_car=rental_only&city=18     754215
# sberauto.com/cars/f28947a1?rental_page=rental_car                                                                                                                                                                        264878
# sberauto.com/cars/bf24b977?rental_page=rental_car                                                                                                                                                                        263966
# sberauto.com/cars?utm_source_initial=sbol&utm_medium_initial=banner&utm_campaign_initial=LEoPHuyFvzoNfnzGgfcd&city=1&rental_page=rental_only&rental_car=rental_only&city=18                                              257588
# sberauto.com/cars?city=1&city=18&rental_page=rental_only&rental_car=rental_only&page=1                                                                                                                                   199098
# sberauto.com/cars/bfc21661?rental_page=rental_car                                                                                                                                                                        187602
# sberauto.com/cars/2fc745ed?rental_page=rental_car                                                                                                                                                                        168387
# sberauto.com/cars/all/skoda/rapid/bf24b977?rental_page=rental_car                                                                                                                                                        168352
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: event_category
# Пропуски: 127776 (0.8%)
# Уникальных значений: 53
#
# Все значения:
# ['sub_page_view' 'listing_ads' 'card_web' 'sub_button_click' 'search_form'
#  'my_idea' 'quiz' nan 'jivosite' 'cars' 'ad_banner' 'main_banners'
#  'active_invitation' 'sap_search_form' 'sub_submit' 'footer'
#  'sap_search__form' 'auth' 'chat' 'scrolling_main_page' 'offers'
#  'greenday_sub_button_click' 'greenday_listing_ads' 'navigation'
#  'greenday_gtm.triggergroup' 'phone' 'profile_menu' 'main_services'
#  'header' 'main_advantages' 'greenday_sub_submit' 'category_tile' 'add_ad'
#  'add_ad_options' 'add_ad_price' 'add_ad_city'
#  'add_ad_additional_information' 'add_ad_documents' 'add_ad_description'
#  'add_ad_photo' 'add_ad_vin' 'add_ad_publish_success' 'add_ad_preview'
#  'credit_landing_pos' 'greenday_sub_page_view' 'credit_buttons'
#  'add_ad_form' 'wallet' 'pos_landing' 'app_banner' 'titul_form'
#  'greenday_card_web' 'tesla']
#
# Топ-10 значений:
# event_category
# card_web            7456998
# search_form         2423605
# sub_page_view       1986074
# sub_button_click    1073471
# listing_ads         1040468
# cars                 358915
# sap_search_form      356596
# quiz                 263134
# auth                 189373
# sap_search__form     188129
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: event_action
# Пропуски: 127776 (0.8%)
# Уникальных значений: 231
#
# Слишком много значений (> 100). Примеры:
# ['sap_search_form_cost_to' 'view_new_card' 'view_card' 'photos'
#  'proactive invitation shown' 'view_more_click']
#
# Топ-10 значений:
# event_action
# view_card                  3558985
# view_new_card              3551009
# sub_landing                1798117
# go_to_car_card              973666
# sub_view_cars_click         791515
# search_form_region          512069
# search_form_search_btn      433748
# sap_search_form_cost_to     356596
# showed_number_ads           326274
# pagination_click            248944
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: event_label
# Пропуски: 3887960 (24.5%)
# Уникальных значений: 39826
#
# Слишком много значений (> 100). Примеры:
# ['KclpemfoHstknWHFiLit' 'hAHqGICPFQiPwtzubOzs' 'laGwZrsmhPBUTfmuxIBJ'
#  'yatapsJsSVhXEatMiuad' 'OHfyUfDKdPgBdvelDlfG' 'IVnHYBjOnVYVppvrUpwj']
#
# Топ-10 значений:
# event_label
# KclpemfoHstknWHFiLit    6505447
# NaN                     3887960
# hAHqGICPFQiPwtzubOzs    1284914
# OHfyUfDKdPgBdvelDlfG     626554
# pzAKUYdRKNEUXxxBFUPX     358915
# ghOrjqpgskpGHSFfBBsi     342500
# vodKSlUobUWTVlgsJqdI     164800
# MbQsNZxBQkusqOKQZfWz      91248
# yatapsJsSVhXEatMiuad      87587
# exyNyRcKbRJNDavyEYoX      86305
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: event_value
# Пропуски: 15854246 (100.0%)
# Уникальных значений: 2
#
# Все значения:
# [None nan]
#
# Топ-10 значений:
# event_value
# None    15726470
# NaN       127776
# Name: count, dtype: int64
#
# ------------------------------------------------------------
# Полный анализ колонки: is_target
# Пропуски: 0 (0.0%)
# Уникальных значений: 2
#
# Все значения:
# [0 1]
#
# Описательная статистика:
# count   15854246.00
# mean           0.16
# std            0.36
# min            0.00
# 25%            0.00
# 50%            0.00
# 75%            0.00
# max            1.00
# Name: is_target, dtype: float64

# %%
# X и y
X = data.drop('is_target', axis=1)
y = data['is_target']

# создаём Pool (рекомендуется при наличии категориальных)
cat_feats = ['session_id','client_id','utm_source','utm_medium',
             'utm_campaign', 'utm_adcontent', 'utm_keyword',
             'device_category', 'device_os', 'device_brand', 'device_browser',
             'geo_country',	'geo_city', 'hit_referer',
             'hit_page_path', 'event_category', 'event_action', 'event_label']
train_pool = Pool(X, y, cat_features=cat_feats)

# обучение
model = CatBoostClassifier(
    iterations=100,
    learning_rate=0.1,
    depth=6,
    verbose=50
)
model.fit(train_pool)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# File _catboost.pyx:2600, in _catboost.get_cat_factor_bytes_representation()
#
# File _catboost.pyx:2115, in _catboost.get_id_object_bytes_string_representation()
#
# CatBoostError: bad object for id: nan
#
# During handling of the above exception, another exception occurred:
#
# CatBoostError                             Traceback (most recent call last)
# Cell In[9], line 11
#       5 # создаём Pool (рекомендуется при наличии категориальных)
#       6 cat_feats = ['session_id','client_id','utm_source','utm_medium',
#       7              'utm_campaign', 'utm_adcontent', 'utm_keyword',
#       8              'device_category', 'device_os', 'device_brand', 'device_browser',
#       9              'geo_country',	'geo_city', 'hit_referer',
#      10              'hit_page_path', 'event_category', 'event_action', 'event_label']
# ---> 11 train_pool = Pool(X, y, cat_features=cat_feats)
#      13 # обучение
#      14 model = CatBoostClassifier(
#      15     iterations=100,
#      16     learning_rate=0.1,
#      17     depth=6,
#      18     verbose=50
#      19 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/catboost/core.py:855, in Pool.__init__(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, column_description, pairs, graph, delimiter, has_header, ignore_csv_quoting, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count, log_cout, log_cerr, data_can_be_none)
#     849         if isinstance(feature_names, PATH_TYPES):
#     850             raise CatBoostError(
#     851                 "feature_names must be None or have non-string type when the pool is created from "
#     852                 "python objects."
#     853             )
# --> 855         self._init(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight,
#     856                    group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#     857 elif not data_can_be_none:
#     858     raise CatBoostError("'data' parameter can't be None")
#
# File /opt/anaconda3/lib/python3.12/site-packages/catboost/core.py:1491, in Pool._init(self, data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight, group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#    1489 if feature_tags is not None:
#    1490     feature_tags = self._check_transform_tags(feature_tags, feature_names)
# -> 1491 self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, graph, weight,
#    1492                 group_id, group_weight, subgroup_id, pairs_weight, baseline, timestamp, feature_names, feature_tags, thread_count)
#
# File _catboost.pyx:4329, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4381, in _catboost._PoolBase._init_pool()
#
# File _catboost.pyx:4190, in _catboost._PoolBase._init_features_order_layout_pool()
#
# File _catboost.pyx:3087, in _catboost._set_features_order_data_pd_data_frame()
#
# File _catboost.pyx:2607, in _catboost.get_cat_factor_bytes_representation()
#
# CatBoostError: Invalid type for cat_feature[non-default value idx=24973,feature_idx=1]=nan : cat_features must be integer or string, real number values and NaN values should be converted to string.
